# %%
from pyspark.sql.functions import current_timestamp
from dateutil.relativedelta import relativedelta

# %%
"""
create dataframe from ALL (*) parquet files in the yellow directory
verify by displaying first 10 rows
"""

# get two months ago from the current date
two_months_ago = date.today() - relativedelta(months=2)
formatted_date = two_months_ago.strftime("%Y-%m")

df = spark.read.parquet(f'/Volumes/workspace/00_landing/data_sources/nyctaxi_yellow/{formatted_date}')
display(df.limit(10))

# %%
"""
transformation:
add current timestamp as new column 'processed_timestamp'
"""
df = df.withColumn("processed_timestamp", current_timestamp())

# %%
"""
execution:
write new table with taxi cab data
"""
df.write.saveAsTable('01_bronze.yellow_trips_raw', mode='append')
