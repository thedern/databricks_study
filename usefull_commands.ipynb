# %%
# run other code/notebook from current notebook
# this allows access to the 'state' (functions/variables/classes) created in that external code, locally
# %run "./<path to other notebook or py file>"

# %%
# pip install libraries, then import lib as normally would in python
# %pip install <lib name>

# %%
# secret-scopes

# %%
# Azure Key vaults

# %%
# help
# to get help on anything
# help(<function name>)
# see example below
import numpy
help(numpy.random.normal)

# %%
# %sql
-- drop catalog
DROP CATALOG streaming_demo CASCADE
